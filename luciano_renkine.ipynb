# %% [markdown]
# # Assignment
#
# The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).
#
#
# **MAKE SURE TO MAKE A COPY OF THIS ASSIGNMENT IN YOUR OWN REPOSITORY.** (delete this line in your new copy :) )

# %% [markdown]
# # [EXERCISE 1]
# ## Luciano Renkine, lrenkine@mail.austral.edu.ar
#
# ![Universidad Austral](https://campusvirtual.austral.edu.ar/pluginfile.php/1/theme_lambda/slide1image/1711108774/IMG_9247%20%281%29.jpg)
#
# La imagen muestra mi universidad actual.

# %% [markdown]
# ---

# %% [markdown]
# # [EXERCISE 5]

# %%
a = 3
b = 7

# %% [markdown]
# ## Suma

# %%
print(a+b)
# Out:
# 10

# %% [markdown]
# ## Resta

# %%
print(a-b)
# Out:
# -4

# %% [markdown]
# ## Multiplicación

# %%
print(a*b)
# Out:
# 21

# %% [markdown]
# ## División

# %%
print(a/b)
# Out:
# 0.42857142857142855
